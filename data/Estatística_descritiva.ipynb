# %%
# Importações
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
plt.style.use('seaborn-v0_8')
# %matplotlib inline

# %%
# Carregando os dados 
df = pd.read_csv(r'C:\Users\laura\OneDrive\Documentos\GitHub\Bootcamp-Finor\data\ibov_retornos_simples.csv', index_col=0, parse_dates=True)
print(df.shape)
df.head()
# Out:
# (1818, 62)
#             ABEV3.SA  AXIA3.SA  AXIA6.SA  AZZA3.SA  B3SA3.SA  BBAS3.SA  \
# Date
# 2018-01-03  0.002305 -0.012773 -0.016026  0.030195  0.017023  0.012754
# 2018-01-04 -0.005520 -0.006469  0.014425  0.031552  0.006438  0.009595
# 2018-01-05  0.003700 -0.009224 -0.025229 -0.033595  0.014499  0.000000
# 2018-01-08 -0.001843  0.006572  0.002353 -0.012279  0.004624  0.002376
# 2018-01-09 -0.002770 -0.039717 -0.042253 -0.006304 -0.014226 -0.009482
#
#             BBDC3.SA  BBDC4.SA  BBSE3.SA  BEEF3.SA  ...  TAEE11.SA  TIMS3.SA  \
# Date                                                ...
# 2018-01-03  0.004254  0.004598  0.000697 -0.007346  ...   0.001398  0.000757
# 2018-01-04  0.018209  0.016407  0.002089 -0.003700  ...  -0.015822 -0.004542
# 2018-01-05  0.000304  0.005665  0.006602  0.011142  ...   0.004728  0.008365
# 2018-01-08  0.000000 -0.000282  0.005868 -0.033976  ...  -0.004706 -0.013574
# 2018-01-09 -0.007576 -0.009295 -0.003432 -0.001901  ...  -0.018440  0.001529
#
# ...

# %%
import os
os.path.exists(r'C:\Users\laura\OneDrive\Documentos\GitHub\Bootcamp-Finor\data\ibov_retornos_simples.csv')
# Out:
# True

# %%
# Estatísticas descritivas básicas 
desc = df.describe().T
desc['skewness'] = df.skew()
desc['kurtosis'] = df.kurtosis()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
display(desc)
# Out:
#             count      mean       std       min       25%       50%       75%  \
# ABEV3.SA   1818.0  0.000102  0.017863 -0.157818 -0.008785  0.000000  0.008693
# AXIA3.SA   1818.0  0.001045  0.030244 -0.195052 -0.014073  0.000275  0.014966
# AXIA6.SA   1818.0  0.001036  0.026968 -0.193256 -0.011855  0.000283  0.013891
# AZZA3.SA   1818.0  0.000115  0.026151 -0.166667 -0.014555 -0.000567  0.014369
# B3SA3.SA   1818.0  0.000764  0.024869 -0.161204 -0.013430  0.000000  0.014491
# BBAS3.SA   1818.0  0.000856  0.022779 -0.166895 -0.009973  0.000711  0.011487
# BBDC3.SA   1818.0  0.000234  0.021494 -0.160127 -0.011030  0.000364  0.010938
# BBDC4.SA   1818.0  0.000263  0.022032 -0.173843 -0.011061  0.000000  0.011300
# BBSE3.SA   1818.0  0.000700  0.016153 -0.095077 -0.008100  0.000803  0.009149
# BEEF3.SA   1818.0  0.000183  0.028089 -0.185748 -0.015097 -0.000999  0.015031
# BPAC11.SA  1818.0  0.001677  0.028373 -0.268633 -0.012615  0.000305  0.015625
# ...

# %%
desc.to_excel('estatisticas_descritivas.xlsx')
print('Salvo')
# Out:
# Salvo
